# %%
#CONFIG BOX

example={"key_1": "value_1", "key_2": "value_2"}

# %%
example["key_1"]
# Out:
# 'value_1'

# %%
example.key_1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 example.key_1
#
# AttributeError: 'dict' object has no attribute 'key_1'

# %%
from box import ConfigBox
example=ConfigBox({"key_1": "value_1", "key_2": "value_2"})

# %%
example.key_1
# Out:
# 'value_1'

# %%
#ENSURE

def get_product(x: int, y: int) -> int:
    return x * y

# %%
print(get_product(2, 3))
print(get_product(2, "3"))
# Out:
# 6
# 33

# %%
from ensure import ensure_annotations

@ensure_annotations
def get_product(x: int, y: int) -> int:
    return x * y

# %%
print(get_product(2, 3))
print(get_product(2, "3"))
# Out:
# 6
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 print(get_product(2, 3))
# ----> 2 print(get_product(2, "3"))
#
# File c:\Users\godje\OneDrive\Escritorio\Data-Science-Project-Stroke-Prediction-\venv\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000019AA6FA2E50> does not match annotation type <class 'int'>
